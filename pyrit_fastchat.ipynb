# %%
# !git clone https://github.com/varshini2305/PyRIT.git
# Out:
# Cloning into 'PyRIT'...
# remote: Enumerating objects: 13247, done.
# remote: Counting objects: 100% (541/541), done.
# remote: Compressing objects: 100% (337/337), done.
# remote: Total 13247 (delta 349), reused 204 (delta 204), pack-reused 12706 (from 2)
# Receiving objects: 100% (13247/13247), 128.88 MiB | 30.34 MiB/s, done.
# Resolving deltas: 100% (9721/9721), done.

# %%
# !pwd
# Out:
# /content

# %%
import os
os.chdir("/content/PyRIT/pyrit/auxiliary_attacks/gcg/experiments")

# %%
# !pwd
# Out:
# /content/PyRIT/pyrit/auxiliary_attacks/gcg/experiments

# %%
# !ls
# Out:
# configs  __init__.py  log.py  README.md  run.py  train.py

# %%
inputs={
        "model_name": "phi_3_mini",
        "setup": "multiple",
        "n_train_data": 3,
        "n_test_data": 0,
        "n_steps": 1,
        "batch_size": 128,
    }

# %%
print(f"!python run.py --model_name {inputs['model_name']} --setup {inputs['setup']} --n_train_data {inputs['n_train_data']} --n_test_data {inputs['n_test_data']} --n_steps {inputs['n_steps']} --batch_size {inputs['batch_size']}")
# Out:
# !python run.py --model_name phi_3_mini --setup multiple --n_train_data 3 --n_test_data 0 --n_steps 1 --batch_size 128

# %%
import os
os.environ["PYTHONPATH"] += os.pathsep + "/content/PyRIT"

# %%
# !echo $PYTHONPATH
# Out:
# /env/python:/content/PyRIT

# %% [markdown]
# Install dependencies

# %%
# !pip install mlflow
# !pip install ml-collections
# !pip install appdirs
# !pip install azure-core
# !pip install azure-ai-ml azure-identity
# !pip install tinytag
# !pip install python-dotenv

# %%
# !pip install git+https://github.com/lm-sys/FastChat.git@2c68a13bfe10b86f40e3eefc3fcfacb32c00b02a

# %%
import os

os.environ["HUGGINGFACE_TOKEN"] = HUGGINGFACE_TOKEN

# %%
# !python run.py --model_name phi_3_mini --setup multiple --n_train_data 3 --n_test_data 0 --n_steps 1 --batch_size 128
# Out:
# python3: can't open file '/content/run.py': [Errno 2] No such file or directory

# %% [markdown]
# with a modified AttackPrompt _update_ids()

# %%
# !python run.py --model_name phi_3_mini --setup multiple --n_train_data 3 --n_test_data 0 --n_steps 1 --batch_size 128
# Out:
# 2025-07-28 14:38:52.318263: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753713532.335508    4891 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753713532.340451    4891 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-28 14:38:52.358769: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 8 (delta 4), reused 8 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (8/8), 727 bytes | 80.00 KiB/s, done.
# From https://github.com/varshini2305/PyRIT
#    7d1b382..5b9f50c  main       -> origin/main
# Updating 7d1b382..5b9f50c
# Fast-forward
#  pyrit/auxiliary_attacks/gcg/attack/base/attack_manager.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !python run.py --model_name phi_3_mini --setup multiple --n_train_data 3 --n_test_data 0 --n_steps 1 --batch_size 128
# Out:
# 2025-07-28 15:13:22.317000: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753715602.337383   13756 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753715602.343448   13756 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-28 15:13:22.363341: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import torch

def print_cuda_memory(tag=""):
    allocated = torch.cuda.memory_allocated() / 1024**3
    reserved  = torch.cuda.memory_reserved()  / 1024**3
    print(f"{tag} → allocated: {allocated:.2f} GB, reserved: {reserved:.2f} GB")

# %%
# before clearing
print_cuda_memory("Before empty_cache")

# clear cache
torch.cuda.empty_cache()

# after clearing
print_cuda_memory("After empty_cache")
# Out:
# Before empty_cache → allocated: 0.00 GB, reserved: 0.00 GB
# After empty_cache → allocated: 0.00 GB, reserved: 0.00 GB
